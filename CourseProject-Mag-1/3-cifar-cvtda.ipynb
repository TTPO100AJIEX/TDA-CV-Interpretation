# %%
import numpy
import torchvision

DATASET = "E:/DiplomaV2/full_run_2/cifar-10/results"

train = torchvision.datasets.CIFAR10('cifar-10', train = True, download = True)
test = torchvision.datasets.CIFAR10('cifar-10', train = False, download = False)

train_images = numpy.array([numpy.array(item[0]) / 255 for item in train])
train_labels = numpy.array([item[1] for item in train])

test_images = numpy.array([numpy.array(item[0]) / 255 for item in test])
test_labels = numpy.array([item[1] for item in test])
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to cifar-10\cifar-10-python.tar.gz
# 100%|██████████| 170M/170M [00:26<00:00, 6.33MB/s]
# Extracting cifar-10\cifar-10-python.tar.gz to cifar-10

# %%
import cvtda.topology

fe = cvtda.topology.FeatureExtractor(n_jobs = 1)
train_features = fe.fit_transform(train_images, dump_name = f'{DATASET}/train')
test_features = fe.transform(test_images, dump_name = f'{DATASET}/test')
# Out:
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 50000/50000 [00:00<00:00, 96165.27it/s]
# GreyscaleExtractor: processing E:/DiplomaV2/full_run_2/cifar-10/results/train/greyscale/gray, do_fit = True
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/train/greyscale/gray/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/train/greyscale/gray/features.npy
# GreyscaleExtractor: processing E:/DiplomaV2/full_run_2/cifar-10/results/train/greyscale/red, do_fit = True
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/train/greyscale/red/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/train/greyscale/red/features.npy
# GreyscaleExtractor: processing E:/DiplomaV2/full_run_2/cifar-10/results/train/greyscale/green, do_fit = True
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/train/greyscale/green/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/train/greyscale/green/features.npy
# GreyscaleExtractor: processing E:/DiplomaV2/full_run_2/cifar-10/results/train/greyscale/blue, do_fit = True
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/train/greyscale/blue/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/train/greyscale/blue/features.npy
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 50000/50000 [00:00<00:00, 100712.43it/s]
# GreyscaleExtractor: processing E:/DiplomaV2/full_run_2/cifar-10/results/train/inverted_greyscale/gray, do_fit = True
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/train/inverted_greyscale/gray/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/train/inverted_greyscale/gray/features.npy
# GreyscaleExtractor: processing E:/DiplomaV2/full_run_2/cifar-10/results/train/inverted_greyscale/red, do_fit = True
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/train/inverted_greyscale/red/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/train/inverted_greyscale/red/features.npy
# GreyscaleExtractor: processing E:/DiplomaV2/full_run_2/cifar-10/results/train/inverted_greyscale/green, do_fit = True
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/train/inverted_greyscale/green/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/train/inverted_greyscale/green/features.npy
# GreyscaleExtractor: processing E:/DiplomaV2/full_run_2/cifar-10/results/train/inverted_greyscale/blue, do_fit = True
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/train/inverted_greyscale/blue/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/train/inverted_greyscale/blue/features.npy
# Fitting filtrations
# 100%|██████████| 72/72 [27:07<00:00, 22.60s/it]
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 50000/50000 [00:00<00:00, 120462.84it/s]
# RGB images received. Transforming to grayscale.
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/train/geometry/rgb/features.npy
# rgb2gray: 100%|██████████| 50000/50000 [00:00<00:00, 125139.60it/s]
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/train/geometry/gray/features.npy
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/train/geometry/red/features.npy
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/train/geometry/green/features.npy
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/train/geometry/blue/features.npy
# Applying StandardScaler.
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 10000/10000 [00:00<00:00, 109203.06it/s]
# GreyscaleExtractor: processing E:/DiplomaV2/full_run_2/cifar-10/results/test/greyscale/gray, do_fit = False
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/test/greyscale/gray/diagrams.npy
# Applying Scaler to persistence diagrams.
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/test/greyscale/gray/features.npy
# GreyscaleExtractor: processing E:/DiplomaV2/full_run_2/cifar-10/results/test/greyscale/red, do_fit = False
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/test/greyscale/red/diagrams.npy
# Applying Scaler to persistence diagrams.
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/test/greyscale/red/features.npy
# GreyscaleExtractor: processing E:/DiplomaV2/full_run_2/cifar-10/results/test/greyscale/green, do_fit = False
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/test/greyscale/green/diagrams.npy
# Applying Scaler to persistence diagrams.
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/test/greyscale/green/features.npy
# GreyscaleExtractor: processing E:/DiplomaV2/full_run_2/cifar-10/results/test/greyscale/blue, do_fit = False
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/test/greyscale/blue/diagrams.npy
# Applying Scaler to persistence diagrams.
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/test/greyscale/blue/features.npy
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 10000/10000 [00:00<00:00, 131102.32it/s]
# GreyscaleExtractor: processing E:/DiplomaV2/full_run_2/cifar-10/results/test/inverted_greyscale/gray, do_fit = False
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/test/inverted_greyscale/gray/diagrams.npy
# Applying Scaler to persistence diagrams.
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/test/inverted_greyscale/gray/features.npy
# GreyscaleExtractor: processing E:/DiplomaV2/full_run_2/cifar-10/results/test/inverted_greyscale/red, do_fit = False
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/test/inverted_greyscale/red/diagrams.npy
# Applying Scaler to persistence diagrams.
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/test/inverted_greyscale/red/features.npy
# GreyscaleExtractor: processing E:/DiplomaV2/full_run_2/cifar-10/results/test/inverted_greyscale/green, do_fit = False
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/test/inverted_greyscale/green/diagrams.npy
# Applying Scaler to persistence diagrams.
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/test/inverted_greyscale/green/features.npy
# GreyscaleExtractor: processing E:/DiplomaV2/full_run_2/cifar-10/results/test/inverted_greyscale/blue, do_fit = False
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/test/inverted_greyscale/blue/diagrams.npy
# Applying Scaler to persistence diagrams.
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/test/inverted_greyscale/blue/features.npy
# Applying filtrations
# 100%|██████████| 72/72 [02:32<00:00,  2.12s/it]
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 10000/10000 [00:00<00:00, 130186.33it/s]
# RGB images received. Transforming to grayscale.
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/test/geometry/rgb/features.npy
# rgb2gray: 100%|██████████| 10000/10000 [00:00<00:00, 109614.89it/s]
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/test/geometry/gray/features.npy
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/test/geometry/red/features.npy
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/test/geometry/green/features.npy
# Got the result from E:/DiplomaV2/full_run_2/cifar-10/results/test/geometry/blue/features.npy
# Applying StandardScaler.

# %%
import cvtda.utils
import sklearn.tree
import cvtda.topology
import sklearn.metrics
import cvtda.classification

def explain_decision_tree(fe: cvtda.topology.FeatureExtractor, dt: sklearn.tree.DecisionTreeClassifier, obj: int):
    target, prediction = test_labels[obj], dt.predict([test_features[obj]])[0]
    match = "✓" if target == prediction else "✗"

    path = dt.decision_path([test_features[obj]]).toarray()[0]
    features_idxs = dt.tree_.feature[numpy.where(path != 0)[0][:-1]]
    feature_names = list(numpy.array(fe.feature_names())[features_idxs])
    return cvtda.utils.FeatureExplanation.display_many(
        [fe.explain(f, test_images[obj]) for f in feature_names],
        title=f"Object {obj}  ·  target: {target}   prediction: {prediction} {match}",
    )

dt = sklearn.tree.DecisionTreeClassifier(max_depth = 8, min_samples_leaf = 100, max_features = 1/3, random_state = 42)
dt.fit(train_features, train_labels)
cvtda.classification.estimate_quality(dt.predict_proba(test_features), test_labels)
# Out:
# {'Accuracy': 0.4149,
#  'AUC-ROC': 0.8106667333333336,
#  'Precision': 0.41387244267019146,
#  'Recall': 0.4149,
#  'F1-score': 0.4122982335399614,
#  'TOP-2 Accuracy': 0.5924,
#  'TOP-3 Accuracy': 0.7052,
#  'TOP-5 Accuracy': 0.8468,
#  'TOP-7 Accuracy': 0.9296,
#  'TOP-9 Accuracy': 0.9814}

# %%
import os
import tqdm
import joblib
import matplotlib.pyplot as plt

def process_item(i):
    plt.rcParams.update({ 'font.size': 13 })
    fig = explain_decision_tree(fe, dt, i)
    y = test_labels[i]
    os.makedirs(f"cvtda_results/cifar-10/{y}", exist_ok=True)
    fig.savefig(f"cvtda_results/cifar-10/{y}/{i}.png")
    fig.savefig(f"cvtda_results/cifar-10/{y}/{i}.svg")
    plt.close(fig)

joblib.Parallel(n_jobs=-1)(joblib.delayed(process_item)(i) for i in tqdm.trange(len(test)))
None
# Out:
# 100%|██████████| 10000/10000 [1:51:24<00:00,  1.50it/s]
